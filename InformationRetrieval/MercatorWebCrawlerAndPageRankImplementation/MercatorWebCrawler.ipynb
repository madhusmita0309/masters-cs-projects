# %%
#pip install parsel

# %%
import urllib.request
#import parsel
from html.parser import HTMLParser
from urllib.parse import urlparse
from parsel import Selector
import networkx as nx

# %%
# with urllib.request.urlopen('https://www.indiatoday.in/') as response:
#     html = response.read()

# %%
# selector = Selector(text=html.decode("utf-8",errors='ignore') )
# pol = selector.css('body').get()

# %%
# doc=[]
# class MyDocGen(HTMLParser):
#     def handle_data(self, data):
#         doc.clear()
#         if data.strip()!="":
#             #print(data)
#             doc.append(data)
# #         print("FRom function")
# #         print(doc)

# %%
class MyHTMLParser(HTMLParser):
    def handle_data(self, data):
        if data.strip()!="":
            print(data)

# %%
def getDataFromUrl(url):
    with urllib.request.urlopen(url) as response:
        html = response.read()
    return html

# %%
def getSelector(html):
    selector = Selector(text=html.decode("utf-8",errors='ignore'))
    return selector

# %%
def getBody(selector):
    pol = selector.css('body').get()
    return pol

# %%
def getUrls(selector):
    urls = selector.xpath('//a/@href').getall()
    return urls

# %%
def processQueueElement(url):
    parsedUrl = urlparse(url)
    data = getDataFromUrl(url)
    selector = getSelector(data)
    body = getBody(selector)
    urls = getUrls(selector)
    for idx,i in enumerate(urls):
        if i.startswith("/"):
            urls[idx] = parsedUrl.scheme+'://'+parsedUrl.netloc+i
            #print(urls[idx])
    return urls

# %%
result={'source':[],'dest':[]} 
class graphLinkInfo :
    def storeGraphlink(graph):
        edges = nx.to_edgelist(graph)
        for edge in edges:
            result['source'].append(edge[0])
            result['dest'].append(edge[1])

# %%
seedurls=['https://www.indiatoday.in/','https://www.geeksforgeeks.org/',
         'https://www.flipkart.com/','https://en.wikipedia.org/wiki/Cryptography',
          'https://en.wikipedia.org/wiki/Tourism_in_Goa']

for link in seedurls:
    try:
        urllib.request.urlopen(link)
        urls = processQueueElement(link)
        graph = nx.DiGraph()

        for i in urls:
            if not i.startswith("#"):
                graph.add_edge(link,i)
        
        # use the graph to store source -> target link information for each of the 'links'
        graphLinkInfo.storeGraphlink(graph)
    except urllib.error.HTTPError as err:
        print("Hello")
        pass

# %%
print(result)
# Out:
# {'source': ['https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/', 'https://www.indiatoday.in/' ...

# %%
#graph

# %%
#graph.nodes()

# %%
#graph.edges()

# %%
#nx.draw(graph)

# %%
#import matplotlib.pyplot as plt

# %%
#plt.savefig("graph1.png")

# %%
#plt.show()

# %%
#df = nx.to_pandas_adjacency(graph, dtype=int)

# %%
#type(df)

# %%
#listofedges=nx.to_edgelist(graph,graph.nodes())

# %%
print(type(seedurls))
print(seedurls)
# Out:
# <class 'list'>
# ['https://www.indiatoday.in/', 'https://www.geeksforgeeks.org/', 'https://www.flipkart.com/', 'https://en.wikipedia.org/wiki/Cryptography', 'https://en.wikipedia.org/wiki/Tourism_in_Goa']

# %%
#for i in seedurls:
backqueue1=[]
backqueue2=[]
backqueue3=[]
backqueue4=[]
backqueue5=[]

src = result['source']
dst = result['dest']
backqueue1.append('https://www.indiatoday.in/')
backqueue2.append('https://www.geeksforgeeks.org/')
backqueue3.append('https://www.flipkart.com/')
backqueue4.append('https://en.wikipedia.org/wiki/Cryptography')
backqueue5.append('https://en.wikipedia.org/wiki/Tourism_in_Goa')

for i in range(0,len(src)):
    if src[i] == 'https://www.indiatoday.in/' :
        backqueue1.append(dst[i])
    if src[i] == 'https://www.geeksforgeeks.org/' :
        backqueue2.append(dst[i])
    if src[i] == 'https://www.flipkart.com/' :
        backqueue3.append(dst[i])
    if src[i] == 'https://en.wikipedia.org/wiki/Cryptography' :
        backqueue4.append(dst[i])
    if src[i] == 'https://en.wikipedia.org/wiki/Tourism_in_Goa' :
        backqueue5.append(dst[i])

print(len(result['dest']))
print(len(backqueue1)+len(backqueue2)+len(backqueue3)+len(backqueue4)+len(backqueue5))
# Out:
# 1884
# 1889

# %%
#pip install urlparse

# %%
# url='https://www.indiatoday.in/'
# o=urlparse('https://www.indiatoday.in/trending-news')
# print(o.netloc)
# print(type(o.netloc))

# get netloc / domain of the seed urls:
def checkDomain(src,urlBackqueue):
    s=urlparse(src)
    b=urlparse(urlBackqueue)
    if s.netloc == b.netloc:
        return True
    else :
        return False

# %%
# checkDomain('https://www.imdb.com/',
#             'https://www.imdb.com/offsite/?page-action=ft-amzn-aud&token=BCYnOxS4YoiAwZio-KOJTLWOdwHDTrRzSiIBiQExndQ6rmVjG3yfTf2tvD6yyctfgVXTbs2--kWp%0D%0A7BXe18CPywWdJv4jU59N_-Ktx9HG9asUXySHpJcXhndKDNZnaX6M06lzd983D7yRcWyMQyvREl9T%0D%0AkU8jh3UFCjCaDJsXQKdA7Sk%0D%0A')

# %%
#type(result['dest'][0])
print(seedurls)
# Out:
# ['https://www.indiatoday.in/', 'https://www.geeksforgeeks.org/', 'https://www.flipkart.com/', 'https://en.wikipedia.org/wiki/Cryptography', 'https://en.wikipedia.org/wiki/Tourism_in_Goa']

# %%
dictHostnameToQueue={'https://www.indiatoday.in/':backqueue1,'https://www.geeksforgeeks.org/':backqueue2,
                     'https://www.flipkart.com/':backqueue3,'https://en.wikipedia.org/wiki/Cryptography':backqueue4,
                     'https://en.wikipedia.org/wiki/Tourism_in_Goa':backqueue5
                     }

# %%
print(type(dictHostnameToQueue.get('https://www.indiatoday.in/')))
# Out:
# <class 'list'>

# %%
from queue import PriorityQueue
from urllib.parse import urlparse
import urllib.error
minheap=PriorityQueue()
dupcheck = set()
documents=[]
import time
minheap.put((time.time(),seedurls[0]))
minheap.put((time.time(),seedurls[1]))
minheap.put((time.time(),seedurls[2]))
minheap.put((time.time(),seedurls[3]))
minheap.put((time.time(),seedurls[4]))

# %%
#print(url[1])

# %%
# while not minheap.empty():
#     next_item = minheap.get()
#     print(next_item)
#from random import randint

# %%
class mercator_crawler:
    #def __init__(self):
        #self.resultdict = resultdict
        #self.source=source
        #self.minheap = PriorityQueue()
        #self.backqueue=backqueue
        #self.mostrecenttime=time.time()
        
        
    def crawlwebpage(self):
        while len(finaldocuments) < 100 :
            print(len(finaldocuments))
            if minheap.qsize() == 0:
                minheap.put(topheap)
            topheap=minheap.get()
            timestamp=time.time()+2
            if timestamp > topheap[0] :
                print("Sleeping:")
                time.sleep(3)
            self.backqueue=dictHostnameToQueue.get(topheap[1])
            self.source=topheap[1]
            print("Current source url:",self.source)
            #for i in self.backqueue :
            if len(self.backqueue) > 0:
                try:
                    i=self.backqueue.pop()
                    if(checkDomain(self.source,i)):
                        urllib.request.urlopen(i)
                        if i in dupcheck :
                            print("Duplicate doc!")
                            continue
                        # add to document
                        data = getDataFromUrl(i)
                        selector = getSelector(data)
                        body = getBody(selector)
                        parser=MyDocGen()
                        doc1=parser.feed(body.replace("\\n",""))
                        finaldocuments.append(doc)
                        doc.clear()
                        links=processQueueElement(i)                    
                        for j in links:
                            if not(j.startswith("#")) and (checkDomain(self.source,j)):
                                self.backqueue.append(j)
                                print("Adding to backqueue:",self.source,j)
                                dupcheck.add(j)
                    # add to heap
                        print("Put in minheap",time.time()+randint(0, 3),self.source)
                        minheap.put((time.time()+randint(0, 3),self.source))
                    else:
                        print("Not same domain")
                        print("Source",self.source)
                        print("Domain url",i)
                except (urllib.error.URLError,urllib.error.HTTPError,urllib.error.ContentTooShortError) as e1:
                    print('Download error:',e1.reason)
                    continue
                
            else:
                print("Backqueue Empty")
                continue

# %%
#minheap.qsize()
# Out:
# 5

# %%
# crawl=mercator_crawler()
# crawl.crawlwebpage()

# %%
# print((backqueue4[0]))
# # print(len(backqueue2))
# # print(len(backqueue3))
# # print(len(backqueue4))
# print(len(backqueue5))
# Out:
# https://en.wikipedia.org/wiki/Cryptography
# 365

# %%
doc=[]
class MyDocGen(HTMLParser):
    def handle_data(self, data):
        doc.clear()
        if data.strip()!="":
            #print(data)
            doc.append(data)

# %%
class MyParser(HTMLParser):
    def handle_data(self, data):
        if data.strip()!="":
            doc.append(data)

# %% [markdown]
# - Manual creation of documents from backqueues:

# %%
finaldocuments=[]
itr=0
while ((len(finaldocuments) < 100) or (len(backqueue1) == 0 and len(backqueue2) ==0  and len(backqueue3)== 0  and len(backqueue4) == 0 and len(backqueue5)==0)):
    try:
        #doc.clear()
        
        print("Iteration:",itr)
        
        print("Len of docs",len(finaldocuments))
        index=len(finaldocuments)-1
        if itr > 4:
            itr=0
        
        url=seedurls[itr]
        print("Source",url)
        backqueue=dictHostnameToQueue.get(url)
        if len(backqueue) == 0:
            itr=itr+1
            continue
        i=backqueue.pop()
        #doc.clear()
        print("Current url",i)
        data = getDataFromUrl(i)
        selector = getSelector(data)
        body = getBody(selector)
        parser=MyParser()
        parser.feed(body.replace("\\n",""))
        temp = doc[:]
        if len(doc) > 0:
            finaldocuments.append(temp)
            
        doc.clear()
        itr=itr+1 

    except (urllib.error.URLError,urllib.error.HTTPError,urllib.error.ContentTooShortError) as e1:
        print('Download error:',e1.reason)
        continue
# Out:
# Iteration: 0
# Len of docs 0
# Source https://www.indiatoday.in/
# Current url https://goo.gl/qtxzZf
# Iteration: 1
# Len of docs 1
# Source https://www.geeksforgeeks.org/
# Current url https://twitter.com/geeksforgeeks
# Iteration: 2
# Len of docs 2
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/account/giftcard?otracker=undefined_footer_footer_navlinks
# Iteration: 3
# Len of docs 3
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://wikimediafoundation.org/
# Iteration: 4
# Len of docs 4
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://wikimediafoundation.org/
# Iteration: 5
# Len of docs 5
# Source https://www.indiatoday.in/
# Current url https://www.indiatodaygroup.com/privacy-policy.html
# Iteration: 1
# Len of docs 6
# Source https://www.geeksforgeeks.org/
# Current url https://play.google.com/store/apps/details?id=free.programming.programming&hl=en
# Iteration: 2
# Len of docs 7
# Source https://www.flipkart.com/
# Current url https://brands.flipkart.com
# Iteration: 3
# Len of docs 8
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//en.m.wikipedia.org/w/index.php?title=Cryptography&mobileaction=toggle_view_mobile
# Download error: Not Found
# Iteration: 3
# Len of docs 8
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://foundation.wikimedia.org/wiki/Cookie_statement
# Iteration: 4
# Len of docs 9
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//en.m.wikipedia.org/w/index.php?title=Tourism_in_Goa&mobileaction=toggle_view_mobile
# Download error: Not Found
# Iteration: 4
# Len of docs 9
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://foundation.wikimedia.org/wiki/Cookie_statement
# Iteration: 5
# Len of docs 10
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/newsletter
# Iteration: 1
# Len of docs 11
# Source https://www.geeksforgeeks.org/
# Current url https://in.linkedin.com/company/geeksforgeeks
# Download error: Request denied
# Iteration: 1
# Len of docs 11
# Source https://www.geeksforgeeks.org/
# Current url https://www.facebook.com/GeeksforGeeks-316764689022/timeline/
# Iteration: 2
# Len of docs 12
# Source https://www.flipkart.com/
# Current url https://seller.flipkart.com/?utm_source=fkwebsite&utm_medium=websitedirect
# Iteration: 3
# Len of docs 13
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://stats.wikimedia.org/v2/#/en.wikipedia.org
# Iteration: 4
# Len of docs 14
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://stats.wikimedia.org/v2/#/en.wikipedia.org
# Iteration: 5
# Len of docs 15
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/news.html
# Iteration: 1
# Len of docs 16
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/how-to-contribute-videos-to-geeksforgeeks/
# Iteration: 2
# Len of docs 17
# Source https://www.flipkart.com/
# Current url tel:18002089898
# Download error: unknown url type: tel
# Iteration: 2
# Len of docs 17
# Source https://www.flipkart.com/
# Current url https://www.youtube.com/flipkart
# Iteration: 3
# Len of docs 18
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# Iteration: 4
# Len of docs 19
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# Iteration: 5
# Len of docs 20
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/sitemap
# Iteration: 1
# Len of docs 21
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/write-interview-experience/
# Iteration: 2
# Len of docs 22
# Source https://www.flipkart.com/
# Current url https://www.twitter.com/flipkart
# Iteration: 3
# Len of docs 23
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# Iteration: 4
# Len of docs 24
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org/wiki/Wikipedia:General_disclaimer
# Iteration: 5
# Len of docs 25
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/pr-newswire
# Iteration: 1
# Len of docs 26
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/contribute/
# Iteration: 2
# Len of docs 27
# Source https://www.flipkart.com/
# Current url https://www.facebook.com/flipkart
# Iteration: 3
# Len of docs 28
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://foundation.wikimedia.org/wiki/Privacy_policy
# Iteration: 4
# Len of docs 29
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://foundation.wikimedia.org/wiki/Privacy_policy
# Iteration: 5
# Len of docs 30
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/partners.jsp
# Iteration: 1
# Len of docs 31
# Source https://www.geeksforgeeks.org/
# Current url https://practice.geeksforgeeks.org/faq.php
# Iteration: 2
# Len of docs 32
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/ewaste-compliance-tnc?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//www.wikimediafoundation.org/
# Download error: Not Found
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//foundation.wikimedia.org/wiki/Privacy_policy
# Download error: Not Found
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//foundation.wikimedia.org/wiki/Terms_of_Use
# Download error: Not Found
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//creativecommons.org/licenses/by-sa/3.0/
# Download error: Not Found
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://en.wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# Download error: Not Found
# Iteration: 3
# Len of docs 33
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://www.wikidata.org/wiki/Special:EntityPage/Q8789#sitelinks-wikipedia
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//www.wikimediafoundation.org/
# Download error: Not Found
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//foundation.wikimedia.org/wiki/Privacy_policy
# Download error: Not Found
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//foundation.wikimedia.org/wiki/Terms_of_Use
# Download error: Not Found
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//creativecommons.org/licenses/by-sa/3.0/
# Download error: Not Found
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# Download error: Not Found
# Iteration: 4
# Len of docs 34
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://www.wikidata.org/wiki/Special:EntityPage/Q7829149#sitelinks-wikipedia
# Iteration: 5
# Len of docs 35
# Source https://www.indiatoday.in/
# Current url http://www.music-today.com/
# Iteration: 1
# Len of docs 36
# Source https://www.geeksforgeeks.org/
# Current url https://practice.geeksforgeeks.org/topic-tags/
# Iteration: 2
# Len of docs 37
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/sitemap?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 38
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://zh.wikipedia.org/wiki/%E5%AF%86%E7%A0%81%E5%AD%A6
# Iteration: 4
# Len of docs 39
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://ta.wikipedia.org/wiki/%E0%AE%95%E0%AF%8B%E0%AE%B5%E0%AE%BE%E0%AE%B5%E0%AE%BF%E0%AE%B2%E0%AF%8D_%E0%AE%9A%E0%AF%81%E0%AE%B1%E0%AF%8D%E0%AE%B1%E0%AF%81%E0%AE%B2%E0%AE%BE%E0%AE%A4%E0%AF%8D%E0%AE%A4%E0%AF%81%E0%AE%B1%E0%AF%88
# Iteration: 5
# Len of docs 40
# Source https://www.indiatoday.in/
# Current url http://www.caretoday.in/
# Iteration: 1
# Len of docs 41
# Source https://www.geeksforgeeks.org/
# Current url https://practice.geeksforgeeks.org/company-tags/
# Iteration: 2
# Len of docs 42
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/privacypolicy?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 43
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://diq.wikipedia.org/wiki/Kriptolociye
# Iteration: 4
# Len of docs 44
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://pa.wikipedia.org/wiki/%E0%A8%97%E0%A9%8B%E0%A8%86_%E0%A8%B5%E0%A8%BF%E0%A8%9A_%E0%A8%B8%E0%A9%88%E0%A8%B0_%E0%A8%B8%E0%A8%AA%E0%A8%BE%E0%A8%9F%E0%A8%BE
# Iteration: 5
# Len of docs 45
# Source https://www.indiatoday.in/
# Current url http://www.thomsonpress.com/
# Iteration: 1
# Len of docs 46
# Source https://www.geeksforgeeks.org/
# Current url https://www.youtube.com/geeksforgeeksvideos/
# Iteration: 2
# Len of docs 47
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/paymentsecurity?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 48
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://zh-yue.wikipedia.org/wiki/%E5%AF%86%E7%A2%BC%E5%AD%B8
# Iteration: 4
# Len of docs 49
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://it.wikipedia.org/wiki/Turismo_a_Goa
# Iteration: 5
# Len of docs 50
# Source https://www.indiatoday.in/
# Current url https://aajtak.intoday.in/distribution/rio/
# Iteration: 1
# Len of docs 51
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/articles-on-computer-science-subjects-gq/
# Iteration: 2
# Len of docs 52
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/terms?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 53
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://yi.wikipedia.org/wiki/%D7%A7%D7%A8%D7%99%D7%A4%D7%98%D7%90%D7%92%D7%A8%D7%90%D7%A4%D7%99%D7%A2
# Iteration: 4
# Len of docs 54
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://hi.wikipedia.org/wiki/%E0%A4%97%E0%A5%8B%E0%A4%B5%E0%A4%BE_%E0%A4%95%E0%A4%BE_%E0%A4%AA%E0%A4%B0%E0%A5%8D%E0%A4%AF%E0%A4%9F%E0%A4%A8
# Iteration: 5
# Len of docs 55
# Source https://www.indiatoday.in/
# Current url http://theredlab.in/
# Iteration: 1
# Len of docs 56
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/data-structures/
# Iteration: 2
# Len of docs 57
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/returnpolicy?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 58
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://wuu.wikipedia.org/wiki/%E5%AF%86%E7%A0%81%E5%AD%A6
# Iteration: 4
# Len of docs 59
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://gom.wikipedia.org/wiki/%E0%A4%97%E0%A5%8B%E0%A4%82%E0%A4%AF%E0%A4%9A%E0%A5%87%E0%A4%82_%E0%A4%AA%E0%A4%B0%E0%A5%8D%E0%A4%AF%E0%A4%9F%E0%A4%A8
# Iteration: 5
# Len of docs 60
# Source https://www.indiatoday.in/
# Current url https://aajtak.intoday.in/sahitya/2018/
# Iteration: 1
# Len of docs 61
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/fundamentals-of-algorithms/
# Iteration: 2
# Len of docs 62
# Source https://www.flipkart.com/
# Current url https://seller.flipkart.com/fiv?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 63
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://war.wikipedia.org/wiki/Criptografiya
# Iteration: 4
# Len of docs 64
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://cy.wikipedia.org/wiki/Twristiaeth_yng_Ngoa
# Iteration: 5
# Len of docs 65
# Source https://www.indiatoday.in/
# Current url http://www.robbreportindia.com/limitededition/2018/
# Iteration: 1
# Len of docs 66
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/about/contact-us/
# Iteration: 2
# Len of docs 67
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/helpcentre?catalog=55c9c8e2b0000023002c1702&view=CATALOG
# Iteration: 3
# Len of docs 68
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://vi.wikipedia.org/wiki/M%E1%BA%ADt_m%C3%A3_h%E1%BB%8Dc
# Iteration: 4
# Len of docs 69
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://bh.wikipedia.org/wiki/%E0%A4%97%E0%A5%8B%E0%A4%B5%E0%A4%BE_%E0%A4%AE%E0%A5%87%E0%A4%82_%E0%A4%AA%E0%A4%B0%E0%A5%8D%E0%A4%AF%E0%A4%9F%E0%A4%A8
# Iteration: 5
# Len of docs 70
# Source https://www.indiatoday.in/
# Current url http://www.indiatodayconclave.com/
# Iteration: 1
# Len of docs 71
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/privacy-policy/
# Iteration: 2
# Len of docs 72
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/helpcentre?catalog=55c9c6edb000002e002c1701&view=CATALOG
# Iteration: 3
# Len of docs 73
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://ur.wikipedia.org/wiki/%D8%B1%D9%85%D8%B2_%D9%86%DA%AF%D8%A7%D8%B1%DB%8C
# Iteration: 4
# Len of docs 74
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org/w/index.php?title=Tourism_in_Goa&printable=yes
# Iteration: 5
# Len of docs 75
# Source https://www.indiatoday.in/
# Current url https://aajtak.intoday.in/agenda-aajtak/
# Iteration: 1
# Len of docs 76
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/careers/
# Iteration: 2
# Len of docs 77
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/shipping
# Iteration: 3
# Len of docs 78
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://uk.wikipedia.org/wiki/%D0%9A%D1%80%D0%B8%D0%BF%D1%82%D0%BE%D0%B3%D1%80%D0%B0%D1%84%D1%96%D1%8F
# Iteration: 4
# Len of docs 79
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org/w/index.php?title=Special:ElectronPdf&page=Tourism+in+Goa&action=show-download-screen
# Iteration: 5
# Len of docs 80
# Source https://www.indiatoday.in/
# Current url https://www.indiacontent.in/
# Iteration: 1
# Len of docs 81
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/about/
# Iteration: 2
# Len of docs 82
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/pages/payments
# Iteration: 3
# Len of docs 83
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://tr.wikipedia.org/wiki/Kriptografi
# Iteration: 4
# Len of docs 84
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org/w/index.php?title=Special:Book&bookcmd=book_creator&referer=Tourism+in+Goa
# Iteration: 5
# Len of docs 85
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/best-universities
# Iteration: 1
# Len of docs 86
# Source https://www.geeksforgeeks.org/
# Current url https://auth.geeksforgeeks.org/testimonial/?ref=gfg
# Iteration: 2
# Len of docs 87
# Source https://www.flipkart.com/
# Current url https://www.flipkart.com/s/press?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 88
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://tg.wikipedia.org/wiki/%D0%9A%D1%80%D0%B8%D0%BF%D1%82%D0%BE%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D1%8F
# Iteration: 4
# Len of docs 89
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://commons.wikimedia.org/wiki/Category:Tourism_in_Goa
# Iteration: 5
# Len of docs 90
# Source https://www.indiatoday.in/
# Current url https://www.indiatoday.in/bestcolleges/2018
# Iteration: 1
# Len of docs 91
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/the-technical-scripter-event-by-geeksforgeeks-2?utm_source=geeksforgeeks&utm_medium=banner&utm_campaign=GFG_Right_Bottom_TS_2019
# Iteration: 2
# Len of docs 92
# Source https://www.flipkart.com/
# Current url http://stories.flipkart.com/?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 93
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%97%E0%B8%A2%E0%B8%B2%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B9%80%E0%B8%82%E0%B9%89%E0%B8%B2%E0%B8%A3%E0%B8%AB%E0%B8%B1%E0%B8%AA%E0%B8%A5%E0%B8%B1%E0%B8%9A
# Iteration: 4
# Len of docs 94
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://en.wikipedia.org/w/index.php?title=Special:CiteThisPage&page=Tourism_in_Goa&id=926151987
# Iteration: 5
# Len of docs 95
# Source https://www.indiatoday.in/
# Current url http://www.vasantvalley.org/vasantvalley/default.shtml
# Iteration: 1
# Len of docs 96
# Source https://www.geeksforgeeks.org/
# Current url https://www.geeksforgeeks.org/maximize-the-happiness-of-the-groups-on-the-trip/
# Iteration: 2
# Len of docs 97
# Source https://www.flipkart.com/
# Current url https://www.flipkartcareers.com/?otracker=undefined_footer_navlinks
# Iteration: 3
# Len of docs 98
# Source https://en.wikipedia.org/wiki/Cryptography
# Current url https://te.wikipedia.org/wiki/%E0%B0%97%E0%B1%82%E0%B0%A2_%E0%B0%B2%E0%B0%BF%E0%B0%AA%E0%B0%BF_%E0%B0%B6%E0%B0%BE%E0%B0%B8%E0%B1%8D%E0%B0%A4%E0%B1%8D%E0%B0%B0%E0%B0%82
# Iteration: 4
# Len of docs 99
# Source https://en.wikipedia.org/wiki/Tourism_in_Goa
# Current url https://www.wikidata.org/wiki/Special:EntityPage/Q7829149

# %%
len(finaldocuments)
# Out:
# 100
